# %%
from IPython.core.display import Image

# %% [markdown]
# # GC Factors Project Output

# %%
Image(filename='images_factors/PV_differences.png')

# %%
Image(filename='images_factors/PV_mean.png') #note the pairing (triangle/circle on same x. Not all samples have pairs.

# %%
Image(filename='/data/erin/Project_GC/Factors/images/phylumGCa_d.png')

# %%
Image(filename='/data/erin/Project_GC/Factors/images/phylumGCf_t.png')

# %%
# !cat differences.txt
# Out:
# Filename      Environment     Domain              Group Condition   MeanGC
# 4440374            Coral      Viral      ConPorCompHaw         4 47.34901
# 4440378            Coral Prokaryote      ConPorCompHaw         4 44.88060
# 4440370            Coral      Viral      DOCPorCompHaw         5 43.58063
# 4440372            Coral Prokaryote      DOCPorCompHaw         5 44.76783
# 4440279     Water_Marine Prokaryote             FannLI        23 48.08566
# 4440280     Water_Marine      Viral             FannLI        23 38.64743
# 4440062       Fish_Slime      Viral  FishHealGutKentST         7 23.22310
# 4440059       Fish_Slime Prokaryote FishHealSlimKentST         6 53.15867
# 4440065       Fish_Slime      Viral FishHealSlimKentST         6 49.05172
# 4440063       Fish_Slime      Viral   FishMorGutKentST         8 23.69401
# 4440064       Fish_Slime      Viral  FishMorSlimKentST         9 53.68553
# 4440066       Fish_Slime Prokaryote  FishMorSlimKentST         9 51.52502
# ...

# %%
Image(filename='images/merlot_environmentMean.png')

# %%
Image(filename='images/merlot_environmentMean_PH.png')

# %%
from IPython.core.display import Image
Image(filename='images/merlot_environmentMean_Temp.png')

# %%
Image(filename='images/merlot_environmentMean_Moisture.png')

# %%
Image(filename='images/merlot_environmentMean_CN.png')

# %%
Image(filename='images/merlot_environmentMean_Moisture.png')

# %%
Image(filename='images/merlot_environmentMean_Vinyard.png')

# %%
Image(filename='images/merlot_environmentMean_Soil.png')

# %% [markdown]
# # Statistics

# %% [markdown]
# #### Spearman Correlations

# %%
# !cat factorsFormatted_correlations.txt
# Out:
# Spearman Correlations
#
# Merlot Vineyards
# Significance  Act           Bact     Chl      Cren     DT       Eury     Firm     Pro      Spiro    Ten
# Act           NA            0.00024  0.00074  0.08557  0.0      0.00777  0.00163  0.0      0.57526  0.79134
# Bact          0.00024       NA       0.0      0.0      0.00075  0.0351   0.0      0.0039   0.00018  0.92195
# Chl           0.00074       0.0      NA       0.0      0.00018  0.22818  0.0      0.00393  1e-05    0.2671
# Cren          0.08557       0.0      0.0      NA       0.03453  0.0      0.0      0.9583   0.0      0.97003
# DT            0.0           0.00075  0.00018  0.03453  NA       0.04299  0.00097  0.0      0.75632  0.38142
# Eury          0.00777       0.0351   0.22818  0.0      0.04299  NA       0.00079  1e-05    0.00013  0.34911
# Firm          0.00163       0.0      0.0      0.0      0.00097  0.00079  NA       0.17863  0.0      0.8081
# ...

# %%
# !cat factorsFormatted_significance.txt
# Out:
# Significance (p-value) for Spearman Correlations
#
# Merlot Vineyards
# Significance  Act        Bact     Chl       Cren          DT       Eury     Firm     Pro      Spiro    Ten
# Act           NA         0.90819  0.38575   0.80273       0.0836   NA       0.7611   0.76492  0.30886  0.86297
# Bact          0.52717    0.01469  0.7611    NA            0.70918  0.17889  0.81464  0.61656  0.16489  0.76492
# Chl           0.70918    NA       0.62639   0.88633       0.69542  0.90819  NA       0.29706  0.73797  0.04637
# Cren          0.38575    0.30886  0.17889   0.62639       0.29706  NA       0.47768  0.60419  0.53666  0.86297
# DT            0.81464    0.88633  0.47768   NA            0.64593  0.03631  0.80273  0.73797  0.60419  NA
# Eury          0.07204    0.0836   0.52717   0.61656       0.69542  0.04637  0.53666  0.64593  0.07204  NA

# %% [markdown]
# #### Other Correlating Factor Values (Merlot)¶

# %%
[1] -0.0102 <- Carbon/Nitrogen 
[1]  0.055  <- Temperature
[1]  0.4228 <- Sample Extraction Depth
[1]  0.1395 <- Soil Moisture Percentage
[1] -0.0273 <- Carbon Percentage
[1] -0.0066 <- Nitrogen Percentage

# %% [markdown]
# #### Other Correlating Factor Values (Viral-Prokaryote)¶

# %%
[1] -0.0102 <- pH

# %% [markdown]
# #### CRISPR Counts¶

# %%
# !cat crisperCount.txt
# Out:
# {'4520365.3': 0, '4440419.3': 0, '4520385.3': 0, '4520327.3': 0, '4520337.3': 0, '4520377.3': 0, '4520313.3': 0, '4520301.3': 0, '4520321.3': 0, '4440279.3': 0, '4440425.3': 0, '4440426.3': 0, '4520307.3': 2, '4520335.3': 0, '4520351.3': 0, '4440437.3': 0, '4520389.3': 0, '4520361.3': 0, '4520323.3': 0, '4520319.3': 0, '4440434.3': 0, '4440059.3': 0, '4520379.3': 0, '4440435.3': 0, '4520347.3': 0, '4520315.3': 0, '4440373.3': 0, '4440039.3': 1, '4520383.3': 0, '4520343.3': 1, '4440372.3': 1, '4520341.3': 0, '4520363.3': 0, '4520345.3': 0, '4520373.3': 0, '4520317.3': 1, '4520305.3': 1, '4440324.3': 0, '4520393.3': 0, '4520329.3': 1, '4440061.3': 0, '4440037.3': 1, '4520349.3': 0, '4520333.3': 1, '4520325.3': 1, '4520309.3': 1, '4440379.3': 3, '4520311.3': 0, '4440378.3': 0, '4520359.3': 1, '4440416.3': 0, '4520367.3': 0, '4520357.3': 0, '4520331.3': 1, '4520381.3': 0, '4520391.3': 0, '4520353.3': 0, '4440041.3': 0, '4440066.3': 0, '4520387.3': 0, '4520371.3': 0, '4440380.3': 1, '4520
# ...
