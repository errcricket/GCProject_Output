# %% [markdown]
# # GC Factors Project Output

# %%
from IPython.core.display import Image
Image(filename='/data/erin/Project_GC/Analysis/images/PV_differences.png')

# %%
# !cat /data/erin/Project_GC/Viral/differences.txt
# Out:
# Filename      Environment     Domain              Group Condition   MeanGC
# 4440374            Coral      Viral      ConPorCompHaw         4 47.34901
# 4440378            Coral Prokaryote      ConPorCompHaw         4 44.88060
# 4440370            Coral      Viral      DOCPorCompHaw         5 43.58063
# 4440372            Coral Prokaryote      DOCPorCompHaw         5 44.76783
# 4440279     Water_Marine Prokaryote             FannLI        23 48.08566
# 4440280     Water_Marine      Viral             FannLI        23 38.64743
# 4440062       Fish_Slime      Viral  FishHealGutKentST         7 23.22310
# 4440059       Fish_Slime Prokaryote FishHealSlimKentST         6 53.15867
# 4440065       Fish_Slime      Viral FishHealSlimKentST         6 49.05172
# 4440063       Fish_Slime      Viral   FishMorGutKentST         8 23.69401
# 4440064       Fish_Slime      Viral  FishMorSlimKentST         9 53.68553
# 4440066       Fish_Slime Prokaryote  FishMorSlimKentST         9 51.52502
# ...

# %%
from IPython.core.display import Image
Image(filename='/data/erin/Project_GC/Analysis/images/merlot_environmentMean.png')

# %%
from IPython.core.display import Image
Image(filename='/data/erin/Project_GC/Analysis/images/merlot_environmentMean_PH.png')

# %%
from IPython.core.display import Image
Image(filename='/data/erin/Project_GC/Analysis/images/merlot_environmentMean_Temp.png')

# %%
from IPython.core.display import Image
Image(filename='/data/erin/Project_GC/Analysis/images/merlot_environmentMean_Moisture.png')

# %%
from IPython.core.display import Image
Image(filename='/data/erin/Project_GC/Analysis/images/merlot_environmentMean_CN.png')

# %%
from IPython.core.display import Image
Image(filename='/data/erin/Project_GC/Analysis/images/merlot_environmentMean_Moisture.png')

# %%
from IPython.core.display import Image
Image(filename='/data/erin/Project_GC/Analysis/images/merlot_environmentMean_Vinyard.png')

# %%
from IPython.core.display import Image
Image(filename='/data/erin/Project_GC/Analysis/images/merlot_environmentMean_Soil.png')

# %%
# !cat /data/erin/Project_GC/MetaData/Project_16.json
# Out:
# {"samples":[{"envPackage":{"name":"mge54637","data":{"mgrast_id":{"unit":"","required":"0","value":"mge54637","aliases":["",""],"type":"text","definition":"MG-RAST Enviromental Package ID","mixs":"0"},"body_habitat":{"unit":"","required":"0","value":"25 m offshore","aliases":["host-associated_body_habitat","body_habitat"],"type":"text","definition":"original body habitat where the sample was obtained from","mixs":"1"},"host_growth_cond":{"unit":"","required":"0","value":"corals were placed directly into an aquarium containing 5 l of 30°C seawater","aliases":["host-associated_host_growth_cond","host_growth_cond"],"type":"text","definition":"literature reference giving growth conditions of the host","mixs":"1"},"host_subject_id":{"unit":"","required":"0","value":"TempPorCompHawMic200602","aliases":["host-associated_host_subject_id","host_subject_id"],"type":"text","definition":"a unique identifier by which each subject can be referred to, de-identified, e.g. #131","mixs":"1"},"misc_par
# ...
