# %% [markdown]
# # Project Output

# %% [markdown]
# #### The purpose of this notebook is so that my collaborators can see where I am in this process.

# %% [markdown]
# #### Number of sequences

# %%
# !tail -2 mergedStatReport.txt #still processing file# 180
# Out:
# Total number of sequences: 30,114,711
# Number of files: 180

# %% [markdown]
# #### Images

# %%
from IPython.core.display import Image
Image(filename='images/FS_Genome.png') #(n) denotes number of genomes in phylum

# %%
from IPython.core.display import Image
Image(filename='images/environment.png')

# %%
from IPython.core.display import Image
Image(filename='images/Chicken_Cecum.png')

# %%
from IPython.core.display import Image
Image(filename='images/BP_Chicken_Cecum.png')

# %%
from IPython.core.display import Image
Image(filename='images/Contaminated_Soil.png')

# %%
from IPython.core.display import Image
Image(filename='images/BP_Contaminated_Soil.png')

# %%
from IPython.core.display import Image
Image(filename='images/Coral.png')

# %%
from IPython.core.display import Image
Image(filename='images/BP_Coral.png')

# %%
from IPython.core.display import Image
Image(filename='images/Cow_Rumen.png')

# %%
from IPython.core.display import Image
Image(filename='images/BP_Cow_Rumen.png')

# %%
from IPython.core.display import Image
Image(filename='images/Dental_Plaque.png')

# %%
from IPython.core.display import Image
Image(filename='images/BP_Dental_Plaque.png')

# %%
from IPython.core.display import Image
Image(filename='images/Fish_Slime.png')

# %%
from IPython.core.display import Image
Image(filename='images/BP_Fish_Slime.png')

# %%
from IPython.core.display import Image
Image(filename='images/Gut_Fish.png')

# %%
from IPython.core.display import Image
Image(filename='images/BP_Gut_Fish.png')

# %%
from IPython.core.display import Image
Image(filename='images/Gut_Human.png')

# %%
from IPython.core.display import Image
Image(filename='images/BP_Gut_Human.png')

# %%
from IPython.core.display import Image
Image(filename='images/Microbialites.png')

# %%
from IPython.core.display import Image
Image(filename='images/BP_Microbialites.png')

# %%
from IPython.core.display import Image
Image(filename='images/Tundra.png')

# %%
from IPython.core.display import Image
Image(filename='images/BP_Tundra.png')

# %%
from IPython.core.display import Image
Image(filename='images/Water_Marine.png')

# %%
from IPython.core.display import Image
Image(filename='images/BP_Water_Marine.png')

# %%
from IPython.core.display import Image
Image(filename='images/Water_PondFresh.png')

# %%
from IPython.core.display import Image
Image(filename='images/BP_Water_PondFresh.png')

# %%
from IPython.core.display import Image
Image(filename='images/Water_PondSaline.png')

# %%
from IPython.core.display import Image
Image(filename='images/BP_Water_PondSaline.png')

# %%
from IPython.core.display import Image
Image(filename='images/relativeAbundance.png')

# %%
from IPython.core.display import Image
Image(filename='images/HG_relativeAbundance.png') #still needs work

# %%
from IPython.core.display import Image
Image(filename='images/PV_mean.png') #still needs work

# %% [markdown]
# # Statistics

# %% [markdown]
# #### Spearman Correlations (all environments inc.)

# %%
# !cat correlations.txt #This section is complete (all environmental datasets included)
# Out:
# Correlations for All environments
# 	Act	Bact	Chl	Cren	DT	Eury	Firm	Pro	Spiro	Ten
# Act	1.0000	0.1751	-0.0782	0.2170	0.6615	0.5698	0.0391	0.5666	-0.2008	-0.2087
# Bact	0.1751	1.0000	0.5356	0.4518	0.1761	0.5857	0.7552	0.6009	0.6530	0.2531
# Chl	-0.0782	0.5356	1.0000	0.4211	-0.0946	0.3090	0.6103	0.2241	0.6791	0.4523
# Cren	0.2170	0.4518	0.4211	1.0000	0.1293	0.6807	0.2595	0.2882	0.3063	0.2575
# DT	0.6615	0.1761	-0.0946	0.1293	1.0000	0.3222	0.1180	0.4071	-0.1184	-0.2217
# Eury	0.5698	0.5857	0.3090	0.6807	0.3222	1.0000	0.2827	0.6137	0.2284	0.1299
# Firm	0.0391	0.7552	0.6103	0.2595	0.1180	0.2827	1.0000	0.4712	0.7725	0.3607
# Pro	0.5666	0.6009	0.2241	0.2882	0.4071	0.6137	0.4712	1.0000	0.2321	-0.0734
# Spiro	-0.2008	0.6530	0.6791	0.3063	-0.1184	0.2284	0.7725	0.2321	1.0000	0.5974
# Ten	-0.2087	0.2531	0.4523	0.2575	-0.2217	0.1299	0.3607	-0.0734	0.5974	1.0000
#
# Correlations for Human Gut environments
# 	Act	Bact	Chl	Cren	DT	Eury	Firm	Pro	Spiro	Ten
# ...

# %%
# !cat formatted_significance.txt
