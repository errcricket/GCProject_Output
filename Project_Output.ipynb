# %% [markdown]
# # Project Output

# %% [markdown]
# #### The purpose of this notebook is so that my collaborators can see where I am in this process.

# %% [markdown]
# #### Classification Status

# %%
# !cat tracker.txt
# Out:
# Number of completed datasets: 181
# Number of remaining datasets: 1

# %% [markdown]
# #### Number of sequences

# %%
# !tail -2 mergedStatReport.txt #still processing file# 180
# Out:
# Total number of sequences: 24,390,036
# Number of files: 180

# %% [markdown]
# #### Images

# %%
from IPython.core.display import Image
Image(filename='images/FS_Genome.png') #(n) denotes number of genomes in phylum

# %%
from IPython.core.display import Image
Image(filename='images/environment.png')

# %%
from IPython.core.display import Image
Image(filename='images/Chicken_Cecum.png')

# %%
from IPython.core.display import Image
Image(filename='images/Contaminated_Soil.png')

# %%
from IPython.core.display import Image
Image(filename='images/Coral.png')

# %%
from IPython.core.display import Image
Image(filename='images/Cow_Rumen.png')

# %%
from IPython.core.display import Image
Image(filename='images/Dental_Plaque.png')

# %%
from IPython.core.display import Image
Image(filename='images/Fish_Slime.png')

# %%
from IPython.core.display import Image
Image(filename='images/Gut_Fish.png')

# %%
from IPython.core.display import Image
Image(filename='images/Gut_Human.png')

# %%
from IPython.core.display import Image
Image(filename='images/Microbialites.png')

# %%
from IPython.core.display import Image
Image(filename='images/Water_Marine.png')

# %%
from IPython.core.display import Image
Image(filename='images/Water_PondFresh.png')

# %%
from IPython.core.display import Image
Image(filename='images/Water_PondSaline.png')

# %%
from IPython.core.display import Image
Image(filename='images/Tundra.png')
# Out:
# ---------------------------------------------------------------------------
# IOError                                   Traceback (most recent call last)
# <ipython-input-173-b671bb1d26ce> in <module>()
#       1 from IPython.core.display import Image
# ----> 2 Image(filename='images/Tundra_temp.png')
#
# /usr/lib/python2.7/dist-packages/IPython/core/display.pyc in __init__(self, data, url, filename, format, embed, width, height, retina)
#     599         self.height = height
#     600         self.retina = retina
# --> 601         super(Image, self).__init__(data=data, url=url, filename=filename)
#     602
#     603         if retina:
#
# /usr/lib/python2.7/dist-packages/IPython/core/display.pyc in __init__(self, data, url, filename)
#     303         self.filename = None if filename is None else unicode(filename)
#     304
# --> 305         self.reload()
#     306
#     307     def reload(self):
#
# /usr/lib/python2.7/dist-packages/IPython/core/display.pyc in reload(self)
#     621         """Reload the raw data from file or URL."""
#     622         if self.embed:
# --> 623             super(Image,self).reload()
#     624             if self.retina:
#     625                 self._retina_shape()
#
# /usr/lib/python2.7/dist-packages/IPython/core/display.pyc in reload(self)
#     308         """Reload the raw data from file or URL."""
#     309         if self.filename is not None:
# --> 310             with open(self.filename, self._read_flags) as f:
#     311                 self.data = f.read()
#     312         elif self.url is not None:
#
# IOError: [Errno 2] No such file or directory: u'images/Tundra_temp.png'

# %%
from IPython.core.display import Image
Image(filename='images/Water_PondFresh.png')

# %%
from IPython.core.display import Image
Image(filename='images/relativeAbundance.png')

# %% [markdown]
# # Statistics

# %% [markdown]
# #### Spearman Correlations (all environments inc.)

# %%
# !cat correlations.txt
# Out:
# Correlations for all environments
# 	Act	Bact	Chl	Cren	DT	Eury	Firm	Pro	Spiro	Ten
# Act	1.0000	0.1641	-0.0894	0.2074	0.6575	0.5632	0.0270	0.5600	-0.2124	-0.2198
# Bact	0.1641	1.0000	0.5287	0.4429	0.1651	0.5795	0.7517	0.5954	0.6482	0.2439
# Chl	-0.0894	0.5287	1.0000	0.4118	-0.1071	0.2995	0.6044	0.2155	0.6745	0.4441
# Cren	0.2074	0.4429	0.4118	1.0000	0.1167	0.6759	0.2474	0.2788	0.2963	0.2478
# DT	0.6575	0.1651	-0.1071	0.1167	1.0000	0.3124	0.1071	0.3993	-0.1302	-0.2340
# Eury	0.5632	0.5795	0.2995	0.6759	0.3124	1.0000	0.2721	0.6079	0.2183	0.1188
# Firm	0.0270	0.7517	0.6044	0.2474	0.1071	0.2721	1.0000	0.4646	0.7701	0.3519
# Pro	0.5600	0.5954	0.2155	0.2788	0.3993	0.6079	0.4646	1.0000	0.2244	-0.0845
# Spiro	-0.2124	0.6482	0.6745	0.2963	-0.1302	0.2183	0.7701	0.2244	1.0000	0.5942
# Ten	-0.2198	0.2439	0.4441	0.2478	-0.2340	0.1188	0.3519	-0.0845	0.5942	1.0000
#
# Correlations for human environments
# 	Act	Bact	Chl	Cren	DT	Eury	Firm	Pro	Spiro	Ten
# Act	1.0000	0.0060	0.0758	0.0349	0.4483	0.2378	0.0551	0.3877	0.0650	0.0625
# Bact	0.0060	1.0000	0.5682	0.7565	0.0236	0.7104	0.6289	0.5001	0.8015	0.3469
# Chl	0.0758	0.5682	1.0000	0.6287	-0.0032	0.5559	0.5592	0.2666	0.7177	0.3495
# Cren	0.0349	0.7565	0.6287	1.0000	-0.0457	0.7102	0.5622	0.4096	0.7743	0.4411
# DT	0.4483	0.0236	-0.0032	-0.0457	1.0000	-0.0511	0.1662	0.0951	-0.0195	-0.0894
# Eury	0.2378	0.7104	0.5559	0.7102	-0.0511	1.0000	0.4567	0.5160	0.7427	0.4974
# Firm	0.0551	0.6289	0.5592	0.5622	0.1662	0.4567	1.0000	0.4113	0.7848	0.3814
# Pro	0.3877	0.5001	0.2666	0.4096	0.0951	0.5160	0.4113	1.0000	0.4778	0.1250
# Spiro	0.0650	0.8015	0.7177	0.7743	-0.0195	0.7427	0.7848	0.4778	1.0000	0.4898
